# %% [markdown]
# # Main Character Gender Prediction

# %% [markdown]
# Predicting the gender of a main character based on textual data, such as movie reviews, is an interesting and practical problem in Natural Language Processing. This project, “Main Character Gender Prediction”, aims to build a machine learning models (and choose which one is the best) that can classify whether the main character of a given work is male or female, using the textual content of user-generated reviews as the primary data source.

# %%
#Loading the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import joblib
import os
from sklearn.svm import LinearSVC
from sklearn.feature_extraction import text
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# %%
#Loading the dataset
movie_revs = pd.read_csv('../data/movie_reviews.csv')

# %%
movie_revs.head()
# Out:
#    Unnamed: 0  review_id       movie_name    year  reviewer_name  \
# 0           0          1  Lethal Weapon 3  1992.0    J. Boyajian
# 1           1          2  Lethal Weapon 3  1999.0  Frank Maloney
# 2           2          3  Lethal Weapon 3  1995.0       Brian L.
# 3           3          4  Lethal Weapon 3  1979.0   Mark Santora
# 4           4          5  Lethal Weapon 3  1997.0        Jose R.
#
#                                          review_text rated  year_api  \
# 0  About 20 minutes into LETHAL WEAPON 3, my neph...     R      1992
# 1  LETHAL WEAPON 3 is a film directed by Richard ...     R      1992
# 2  120 min., R, Comedy/Action, 1992\nDirector: Ri...     R      1992
# 3  It has been a couple of years since we last sa...     R      1992
# 4  I went to this movie with very low expectation...     R      1992
#
#                      genre       directors  \
# 0  Action, Crime, Thriller  Richard Donner
# 1  Action, Crime, Thriller  Richard Donner
# 2  Action, Crime, Thriller  Richard Donner
# 3  Action, Crime, Thriller  Richard Donner
# 4  Action, Crime, Thriller  Richard Donner
#
#                                         writers  \
# 0  Jeffrey Boam, Robert Mark Kamen, Shane Black
# 1  Jeffrey Boam, Robert Mark Kamen, Shane Black
# 2  Jeffrey Boam, Robert Mark Kamen, Shane Black
# 3  Jeffrey Boam, Robert Mark Kamen, Shane Black
# 4  Jeffrey Boam, Robert Mark Kamen, Shane Black
#
#                                 actors  \
# 0  Mel Gibson, Danny Glover, Joe Pesci
# 1  Mel Gibson, Danny Glover, Joe Pesci
# 2  Mel Gibson, Danny Glover, Joe Pesci
# 3  Mel Gibson, Danny Glover, Joe Pesci
# 4  Mel Gibson, Danny Glover, Joe Pesci
#
#                                                 plot first_genre first_actor  \
# 0  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
# 1  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
# 2  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
# 3  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
# 4  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
#
#    first_director  first_writer first_actor_gender first_director_gender  \
# 0  Richard Donner  Jeffrey Boam             female                  male
# 1  Richard Donner  Jeffrey Boam             female                  male
# 2  Richard Donner  Jeffrey Boam             female                  male
# 3  Richard Donner  Jeffrey Boam             female                  male
# 4  Richard Donner  Jeffrey Boam             female                  male
#
#   first_writer_gender
# 0                male
# 1                male
# 2                male
# 3                male
# 4                male

# %% [markdown]
# ## Data Preprocessing

# %%
#Checking some information about dataset
movie_revs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18862 entries, 0 to 18861
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             18862 non-null  int64
#  1   review_id              18862 non-null  int64
#  2   movie_name             18862 non-null  object
#  3   year                   18491 non-null  float64
#  4   reviewer_name          18862 non-null  object
#  5   review_text            18862 non-null  object
#  6   rated                  17201 non-null  object
#  7   year_api               18862 non-null  int64
#  8   genre                  18855 non-null  object
#  9   directors              18532 non-null  object
#  10  writers                17909 non-null  object
#  11  actors                 18647 non-null  object
#  12  plot                   18214 non-null  object
#  13  first_genre            18855 non-null  object
#  14  first_actor            18647 non-null  object
#  15  first_director         18532 non-null  object
#  16  first_writer           17909 non-null  object
#  17  first_actor_gender     18862 non-null  object
#  18  first_director_gender  18862 non-null  object
#  19  first_writer_gender    18862 non-null  object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 2.9+ MB

# %%
#How many columns is null in the dataset
movie_revs.isnull().sum(axis=0)
# Out:
# Unnamed: 0                  0
# review_id                   0
# movie_name                  0
# year                      371
# reviewer_name               0
# review_text                 0
# rated                    1661
# year_api                    0
# genre                       7
# directors                 330
# writers                   953
# actors                    215
# plot                      648
# first_genre                 7
# first_actor               215
# first_director            330
# first_writer              953
# first_actor_gender          0
# first_director_gender       0
# first_writer_gender         0
# dtype: int64

# %%
#Removing unnecessary column
movie_revs.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')

#Deleting rows that have 'unknown' value in a first_actor_gender column
movie_revs = movie_revs[movie_revs['first_actor_gender'] != 'unknown'].copy()

# %%
#Changing name of the year_api and year column
movie_revs.rename(columns={'year_api': 'year_of_production', 'year': 'year_of_opinion'}, inplace=True)
movie_revs.columns
# Out:
# Index(['review_id', 'movie_name', 'year_of_opinion', 'reviewer_name',
#        'review_text', 'rated', 'year_of_production', 'genre', 'directors',
#        'writers', 'actors', 'plot', 'first_genre', 'first_actor',
#        'first_director', 'first_writer', 'first_actor_gender',
#        'first_director_gender', 'first_writer_gender'],
#       dtype='object')

# %%
#Set the type of year_of_opinion as integer
movie_revs['year_of_opinion'] = movie_revs['year_of_opinion'].astype('Int64')
movie_revs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17652 entries, 0 to 18861
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   review_id              17652 non-null  int64
#  1   movie_name             17652 non-null  object
#  2   year_of_opinion        17290 non-null  Int64
#  3   reviewer_name          17652 non-null  object
#  4   review_text            17652 non-null  object
#  5   rated                  16459 non-null  object
#  6   year_of_production     17652 non-null  int64
#  7   genre                  17647 non-null  object
#  8   directors              17429 non-null  object
#  9   writers                16938 non-null  object
#  10  actors                 17652 non-null  object
#  11  plot                   17218 non-null  object
#  12  first_genre            17647 non-null  object
#  13  first_actor            17652 non-null  object
#  14  first_director         17429 non-null  object
#  15  first_writer           16938 non-null  object
#  16  first_actor_gender     17652 non-null  object
#  17  first_director_gender  17652 non-null  object
#  18  first_writer_gender    17652 non-null  object
# dtypes: Int64(1), int64(2), object(16)
# memory usage: 2.7+ MB

# %%
#Fast chech whether review_id column has all unique values
print(len(movie_revs['review_id']))
print(movie_revs['review_id'].nunique())
# Out:
# 17652
# 17652

# %%
#Filling 'unidentified' in columns rated, genre and first_genre for possibly future charts
to_fill = {'rated': 'unidentified',
          'genre': 'unidentified',
          'first_genre': 'unidentified'
          }

movie_revs.fillna(value=to_fill, inplace=True)

# %%
# This function cleans text by converting it to lowercase, removing HTML tags,
# removing all characters that are not letters or spaces, 
#and replacing multiple consecutive spaces with a single space.
def basic_cleaning(txt):
    txt = txt.lower()
    txt = re.sub(r'<.*?>', ' ', txt)
    txt = re.sub(r'[^a-zA-Z\s]', ' ', txt)
    txt = re.sub(r'\s+', ' ', txt)
    return txt

# %%
#Adding new columns to count the number of words and characters
movie_revs['review_words_count'] = movie_revs['review_text'].apply(lambda x: len(basic_cleaning(str(x)).split()))
movie_revs['review_letters_count'] = movie_revs['review_text'].apply(lambda x: len(basic_cleaning(str(x)).replace(" ", "")))

movie_revs.head(1)
# Out:
#    review_id       movie_name  year_of_opinion reviewer_name  \
# 0          1  Lethal Weapon 3             1992   J. Boyajian
#
#                                          review_text rated  \
# 0  About 20 minutes into LETHAL WEAPON 3, my neph...     R
#
#    year_of_production                    genre       directors  \
# 0                1992  Action, Crime, Thriller  Richard Donner
#
#                                         writers  ...  \
# 0  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...
#
#                                                 plot first_genre first_actor  \
# 0  Martin Riggs and Roger Murtaugh pursue a forme...      Action  Mel Gibson
#
#    first_director  first_writer first_actor_gender first_director_gender  \
# 0  Richard Donner  Jeffrey Boam             female                  male
#
#   first_writer_gender review_words_count  review_letters_count
# 0                male                662                  2848
#
# [1 rows x 21 columns]

# %%
#Cleaning review_text
movie_revs['revew_text_cleaning'] = movie_revs['review_text'].apply(basic_cleaning)
movie_revs.head(1)
# Out:
#    review_id       movie_name  year_of_opinion reviewer_name  \
# 0          1  Lethal Weapon 3             1992   J. Boyajian
#
#                                          review_text rated  \
# 0  About 20 minutes into LETHAL WEAPON 3, my neph...     R
#
#    year_of_production                    genre       directors  \
# 0                1992  Action, Crime, Thriller  Richard Donner
#
#                                         writers  ... first_genre first_actor  \
# 0  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
#
#    first_director  first_writer first_actor_gender first_director_gender  \
# 0  Richard Donner  Jeffrey Boam             female                  male
#
#   first_writer_gender review_words_count review_letters_count  \
# 0                male                662                 2848
#
#                                  revew_text_cleaning
# 0  about minutes into lethal weapon my nephew tur...
#
# [1 rows x 22 columns]

# %%
#Last chceck how the dataset looks after preprocessing
movie_revs.head()
# Out:
#    review_id       movie_name  year_of_opinion  reviewer_name  \
# 0          1  Lethal Weapon 3             1992    J. Boyajian
# 1          2  Lethal Weapon 3             1999  Frank Maloney
# 2          3  Lethal Weapon 3             1995       Brian L.
# 3          4  Lethal Weapon 3             1979   Mark Santora
# 4          5  Lethal Weapon 3             1997        Jose R.
#
#                                          review_text rated  \
# 0  About 20 minutes into LETHAL WEAPON 3, my neph...     R
# 1  LETHAL WEAPON 3 is a film directed by Richard ...     R
# 2  120 min., R, Comedy/Action, 1992\nDirector: Ri...     R
# 3  It has been a couple of years since we last sa...     R
# 4  I went to this movie with very low expectation...     R
#
#    year_of_production                    genre       directors  \
# 0                1992  Action, Crime, Thriller  Richard Donner
# 1                1992  Action, Crime, Thriller  Richard Donner
# 2                1992  Action, Crime, Thriller  Richard Donner
# 3                1992  Action, Crime, Thriller  Richard Donner
# 4                1992  Action, Crime, Thriller  Richard Donner
#
#                                         writers  ... first_genre first_actor  \
# 0  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
# 1  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
# 2  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
# 3  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
# 4  Jeffrey Boam, Robert Mark Kamen, Shane Black  ...      Action  Mel Gibson
#
#    first_director  first_writer first_actor_gender first_director_gender  \
# 0  Richard Donner  Jeffrey Boam             female                  male
# 1  Richard Donner  Jeffrey Boam             female                  male
# 2  Richard Donner  Jeffrey Boam             female                  male
# 3  Richard Donner  Jeffrey Boam             female                  male
# 4  Richard Donner  Jeffrey Boam             female                  male
#
#   first_writer_gender review_words_count review_letters_count  \
# 0                male                662                 2848
# 1                male               1142                 4944
# 2                male                533                 2280
# 3                male                668                 2836
# 4                male                631                 2812
#
#                                  revew_text_cleaning
# 0  about minutes into lethal weapon my nephew tur...
# 1  lethal weapon is a film directed by richard do...
# 2   min r comedy action director richard donner c...
# 3  it has been a couple of years since we last sa...
# 4  i went to this movie with very low expectation...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In this section, we perform exploratory data analysis to better understand the dataset and uncover patterns that may be useful for predicting the gender of the main character.
#
# EDA helps us to:
# - Examine the distribution of key variables, such as review length.
# - Identify common words and phrases used in reviews.
# - Helps visualize the distribution of features across different categories for male and female main characters
# - Generate insights that can guide feature engineering and model selection.
#
# By visualizing and summarizing the data, we can gain a deeper understanding of the textual patterns that may influence the classification task.

# %%
#Creating histograms to visually explore the number of words and characters in reviews

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(movie_revs['review_words_count'], kde=True, ax=axes[0])
axes[0].set_title('How many words reviews have')
axes[0].set_xlabel('Number of Words')       
axes[0].set_ylabel('Number of Reviews') 

sns.histplot(movie_revs['review_letters_count'], kde=True, ax=axes[1])
axes[1].set_title('How many letters reviews have')
axes[1].set_xlabel('Number of Letters')        
axes[1].set_ylabel('Number of Reviews') 

plt.tight_layout()
plt.savefig('../images/review_length_distribution.png')
plt.show()

# %% [markdown]
# The histograms reveal that the distribution of review lengths, measured both by Number of Words and Number of Letters, is strongly right-skewed.
#
# This right-skewed distribution indicates that the majority of reviews are concentrated at the lower end of the length scale. However, the analysis shows a significant density of reviews peaking in the moderate length range (approximately 500–1,000 words and 2,000–4,000 letters).
#
# This high frequency of medium-length reviews is highly beneficial for the NLP model. These reviews are substantial enough to provide rich linguistic context, allowing the model to effectively learn and identify the distinctive patterns that may correlate with the author's gender.

# %%
#Removing common stopwords such as 'is', 'am', 'you', 'with'
my_stopwords = list(text.ENGLISH_STOP_WORDS)

#Creating a vectorizer object ready to transform text into numerical features
vec = CountVectorizer(
    max_features=20,
    stop_words=my_stopwords 
)

#Transforming text into a matrix
matrix = vec.fit_transform(movie_revs['review_text'])

#Summing the counts and getting word names
counts = matrix.sum(axis=0).A1
words = vec.get_feature_names_out()

#Creating DataFrame and sorting
df_words = pd.DataFrame({'Word': words, 'Amount': counts})
df_words = df_words.sort_values('Amount', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(data=df_words, x='Word', y='Amount', hue='Word', palette='flare')
plt.title('Top 20 most used words')
plt.xticks(rotation=90)
plt.xlabel('Words')
plt.savefig('../images/top_20_most_used_words.png')
plt.show()

# %% [markdown]
# This bar chart visualizes the top 20 most frequent words in the dataset after applying standard stop words removal. The most common terms are, as expected, domain-specific, including "film", "reviews", "review", and "movie".
#
# However, an interesting observation from the perspective of our goal — predicting the gender of the main actor — is the absence of gendered pronouns in this top 20 list. This is a direct result of using the standard English stop words list, which automatically filters out pronouns like "he", "she", "him", and "her".
#
# This removal is crucial for our model. By eliminating these explicit gender indicators, we force the model to learn deeper linguistic patterns, such as the usage of specific adjectives or descriptive styles associated with male versus female actors (e.g., analyzing if words like "good", "original", or "responsibility" appear more frequently in reviews of a specific gender). This ensures that our model learns genuine stylistic differences rather than simply counting pronouns, making the prediction task more challenging and meaningful.

# %%
#gender_counter counts how many males and famles are in the dataset
gender_counter = movie_revs.groupby('first_actor_gender').size()

plt.figure(figsize=(12, 6))
sns.barplot(x=gender_counter.index, y=gender_counter.values, hue=gender_counter.index, palette='colorblind', width=0.4)
plt.xlabel('Gender of first actor')
plt.ylabel('Amount of actors')
plt.title('Numbers of actors per gender')
plt.savefig('../images/number_of_actors_per_gender.png')
plt.show()

# %% [markdown]
# This bar chart visualizes the distribution of the target variable—the gender of the first actor gender—revealing a significant class imbalance. The dataset is heavily dominated by films where the first actor is male - over 12,000 entries. Conversely, the female class is the minority, represented by approximately 4,500 entries.
#
# This severe imbalance biases the model toward the majority class (male). Therefore, we can't trust standard Accuracy and must use techniques like class weighting and focus on metrics like F1-score and Recall. Additionally, methods such as normalization or scaling should be applied to any numerical features or next to prediction models to ensure no single feature dominates the model due to its magnitude.

# %%
#Counts movie occurrences, sorts them, and retrieves the top 20 films
movie_counter = (
    movie_revs
    .groupby('movie_name')
    .size()
    .sort_values(ascending=False)
    .head(20)
    .reset_index(name='amount')
)

movie_counter.columns = ['movie_name', 'amount']

#For every movie in a movie_counter assign, gender of a first actor
mapping_year = movie_revs.drop_duplicates('movie_name').set_index('movie_name')['first_actor_gender']
movie_counter['actor_gender'] = movie_counter['movie_name'].map(mapping_year)

plt.figure(figsize=(12, 8))
sns.barplot(data=movie_counter, x='movie_name', y='amount', hue='actor_gender', palette='icefire')
plt.xlabel('Movie name')
plt.ylabel('Amount of reviews')
plt.title('Amount of movie reviews')
plt.xticks(rotation=60, ha='right')
plt.savefig('../images/amount_of_movie_reviews.png')
plt.show()

# %% [markdown]
# The chart lists the top 20 reviewed movies, with "Star Wars: Episode I - The Phantom Menace" leading with 80 reviews. A huge majority of the top-reviewed films prominently feature male first actors, represented by darker bars. There are only three movies, "The X Files", "Contact" and "Allien: Resurrection" where the first actor is female, indicated by the maroon bar. Overall, the visualization demonstrates that movies predominantly featuring a male lead attract a higher volume of reviews in this specific dataset.

# %%
#direct_counter identifies the directors with the highest number of reviews
direct_counter = movie_revs.groupby('first_director').size().sort_values(ascending=False).head(20).reset_index(name='amount')

direct_counter.columns = ['first_director', 'amount']

#For every director in a movie_counter, assign gender
mapping_year = movie_revs.drop_duplicates('first_director').set_index('first_director')['first_director_gender']
direct_counter['director_gender'] = direct_counter['first_director'].map(mapping_year)

plt.figure(figsize=(12, 8))
sns.barplot(data=direct_counter, x='first_director', y='amount', hue='director_gender', palette='pastel')
plt.xlabel('Name of directors')
plt.ylabel('Amount of reviews')
plt.title('Top Directors by Number of Reviews')
plt.xticks(rotation=90)
plt.savefig('../images/top_directors_by_number_of_reviews.png')
plt.show()

# %% [markdown]
# This bar chart, titled "Top Directors by Number of Reviews" illustrates the number of reviews for the most frequently reviewed directors in the dataset, categorized by gender. The most striking observation is the overwhelming dominance of male directors in terms of review volume, occupying the top ranks. Female directors are significantly underrepresented, appearing only once. This pronounced disparity indicates a strong bias in the dataset towards films directed by men. This visualization strongly suggests that models trying to predict reviewer gender might inadvertently learn this underlying gender imbalance in film production and visibility.

# %% [markdown]
# ## Model Building

# %%
#Setting X and y values for train_test_split
X = movie_revs['revew_text_cleaning']
y = movie_revs['first_actor_gender']

# %%
#Train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
#This creates a TF-IDF Vectorizer, a tool that converts text into numerical features
tfidf = TfidfVectorizer(stop_words='english')

#Learning proccess
tfidf.fit(X_train)

#Converting training/test text into sparse matrix
X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
#Setting hyperparameters for future GridSearch
param_grid={
    'tfidf__ngram_range': [(1, 1), (1, 2)],
    'nb__alpha': [0.1, 1.0]
}

# %% [markdown]
# ### First method

# %% [markdown]
# The first model tested in this project is the Multinomial Naive Bayes classifier, a fast and effective algorithm commonly used for text classification tasks. It serves as a strong baseline for evaluating how well word-based features can predict the gender of the actor.

# %%
#This pipeline first converts text into TF-IDF features and then uses a Multinomial Naive Bayes classifier
pipe = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('nb', MultinomialNB())
])

# %%
#Using GridSearched with our pipe and selected param_grid
grid = GridSearchCV(pipe, param_grid, cv=2, n_jobs=-1, scoring='f1_weighted')

#Training GridSearch object
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(stop_words='english')),
#                                        ('nb', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'nb__alpha': [0.1, 1.0],
#                          'tfidf__ngram_range': [(1, 1), (1, 2)]},
#              scoring='f1_weighted')

# %%
print('First model best parameters', grid.best_params_)
# Out:
# First model best parameters {'nb__alpha': 0.1, 'tfidf__ngram_range': (1, 1)}

# %%
print('First model best score', grid.best_score_)
# Out:
# First model best score 0.8306127772500251

# %%
#Predicting labels of the test set
y_pred = grid.predict(X_test)

# %%
print('Accuracy score', accuracy_score(y_test, y_pred))
# Out:
# Accuracy score 0.8949306145567828

# %% [markdown]
# #### Classifcation Report and Confusion Matrix for first model

# %%
classification_report(y_test, y_pred, output_dict=True)
# Out:
# {'female': {'precision': 0.9919678714859438,
#   'recall': 0.5737514518002322,
#   'f1-score': 0.7270051508462104,
#   'support': 861.0},
#  'male': {'precision': 0.8789976920540719,
#   'recall': 0.998501872659176,
#   'f1-score': 0.9349465193757671,
#   'support': 2670.0},
#  'accuracy': 0.8949306145567828,
#  'macro avg': {'precision': 0.9354827817700078,
#   'recall': 0.7861266622297041,
#   'f1-score': 0.8309758351109888,
#   'support': 3531.0},
#  'weighted avg': {'precision': 0.9065443713208069,
#   'recall': 0.8949306145567828,
#   'f1-score': 0.8842420395389085,
#   'support': 3531.0}}

# %%
ConfusionMatrixDisplay.from_estimator(grid, X_test, y_test)
plt.title('Confusion Matrix for First Model')
plt.savefig('../images/confusion_matrix_first_model.png')
plt.show()

# %% [markdown]
# The high accuracy is largely driven by the model’s success on the majority class (Male). Since male actors make up a large portion of the dataset, the model can achieve a good score simply by favoring this class, masking its poor performance on the minority class.
#
# There is a massive disparity in the model's ability to identify relevant instances. It captures nearly every male actor (Recall: 99.9%) but misses more than half of the female actors (Recall: 47.7%). In practice, this means the model is highly prone to False Negatives for the female class, frequently misclassifying reviews about actresses as being about actors.
#
# The Multinomial Naive Bayes classifier serves as a "conservative baseline." It effectively demonstrates that distinct linguistic patterns exist for female leads (evidenced by high precision) but fails to generalize these patterns broadly (evidenced by low recall). To build a truly useful tool, future iterations must prioritize sensitivity for the minority class. This validates the need for the subsequent steps taken in this project, such as implementing class weighting in Logistic Regression and LinearSVC, which directly penalize the model more for missing the minority class, forcing it to learn a more balanced decision boundary.

# %% [markdown]
# ### Second method

# %% [markdown]
# The second model applied in this project is Logistic Regression, a widely used linear classifier for binary and multi-class classification. It models the probability of each class based on the input features, providing a strong baseline for predicting the gender of the main actor from review text.

# %%
#Creating LabelEncoder to convert categorical labels into numeric form
le = LabelEncoder()
y_numeric_types = le.fit_transform(y)

# %%
#Creating a Logistic Regression classifier object, 
#class_weight='balanced' adjusts the weights inversely proportional to class frequencies
log_reg_model = LogisticRegression(class_weight='balanced')

# %%
log_reg_model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
#using the trained Logistic Regression model to make predictions on the test set
log_pred_num = log_reg_model.predict(X_test_tfidf)

# %%
print('Accuracy score', accuracy_score(y_test, log_pred_num))
# Out:
# Accuracy score 0.9340130274709714

# %% [markdown]
# #### Classifcation Report and Confusion Matrix for second model

# %%
classification_report(y_test, log_pred_num, target_names=le.classes_, output_dict=True)
# Out:
# {'female': {'precision': 0.8427947598253275,
#   'recall': 0.8966318234610917,
#   'f1-score': 0.8688801350590883,
#   'support': 861.0},
#  'male': {'precision': 0.9659655831739962,
#   'recall': 0.946067415730337,
#   'f1-score': 0.9559129612109745,
#   'support': 2670.0},
#  'accuracy': 0.9340130274709714,
#  'macro avg': {'precision': 0.9043801714996618,
#   'recall': 0.9213496195957144,
#   'f1-score': 0.9123965481350313,
#   'support': 3531.0},
#  'weighted avg': {'precision': 0.9359315761212622,
#   'recall': 0.9340130274709714,
#   'f1-score': 0.9346908532198178,
#   'support': 3531.0}}

# %%
ConfusionMatrixDisplay.from_predictions(y_test, log_pred_num, display_labels=['female', 'male'])
plt.title('Confusion Matrix for Second Model')
plt.savefig('../images/confusion_matrix_second_model.png')
plt.show()

# %% [markdown]
# The Logistic Regression model, equipped with class weighting (class_weight='balanced'), demonstrates a significant performance improvement over the baseline Multinomial Naive Bayes model. The most notable achievement is the drastic increase in Recall for the "Female" class, which jumped from approximately 57% to nearly 90% (89.66%). This indicates the model is far more capable of correctly identifying the minority class, overcoming the dataset's inherent gender imbalance.
#
# While the Precision for the "Female" class decreased slightly (from ~99% to ~84%), this trade-off is beneficial. The previous model was too conservative, missing almost half of the female actors to avoid false positives. The current model strikes a much healthier balance, correctly capturing the vast majority of female roles while maintaining a respectable precision.
#
# For the "Male" class, performance remains robust with high Precision (96.60%) and Recall (94.61%). Although there is a slight drop in male recall compared to the baseline, the overall F1-scores for both classes are now much closer (0.87 for female vs 0.96 for male), signaling a fairer and more unbiased classifier. The overall accuracy rose to 93.40%, confirming that the model generalizes well across both categories without simply defaulting to the majority class.

# %% [markdown]
# ### Third method

# %% [markdown]
# The third model applied in this project is Linear Support Vector Classification (LinearSVC), a linear classifier that aims to find the hyperplane which best separates classes in the feature space. LinearSVC is effective for high-dimensional data such as TF-IDF representations of text and can serve as a strong alternative to Logistic Regression for predicting the gender of the main actor.

# %%
#Creating LinearSVC object
svc_model = LinearSVC(max_iter=5000)

# %%
#Setting most important hyperparameters for future GridSearch
param_grid_svc = {
    'C': [0.1, 0.5, 1.0, 2.0],
    'penalty': ['l2'],
    'loss': ['hinge', 'squared_hinge']
}

# %%
grid_svc = GridSearchCV(svc_model, param_grid_svc)

# %%
#Training the GridSearchCV object for the LinearSVC model on the training data
grid_svc.fit(X_train_tfidf, y_train)
# Out:
# GridSearchCV(estimator=LinearSVC(max_iter=5000),
#              param_grid={'C': [0.1, 0.5, 1.0, 2.0],
#                          'loss': ['hinge', 'squared_hinge'],
#                          'penalty': ['l2']})

# %%
#Making predictions on the test set using the TF-IDF feature matrix
y_pred_svc = grid_svc.predict(X_test_tfidf)

# %%
print('Best parameters', grid_svc.best_params_)
print('Best score', grid_svc.best_score_)
# Out:
# Best parameters {'C': 2.0, 'loss': 'hinge', 'penalty': 'l2'}
# Best score 0.9470285040988744

# %%
print('Accuracy score', accuracy_score(y_test, y_pred_svc))
# Out:
# Accuracy score 0.9532710280373832

# %%
#Saving our model
if not os.path.exists('../models'):
    os.makedirs('../models')

model_to_save = grid_svc.best_estimator_
joblib.dump(model_to_save, '../models/linear_svc_model.joblib')
# Out:
# ['../models/linear_svc_model.joblib']

# %% [markdown]
# #### Classifcation Report and Confusion Matrix for thrid model

# %%
classification_report(y_test, y_pred_svc, output_dict=True)
# Out:
# {'female': {'precision': 0.9371859296482412,
#   'recall': 0.8664343786295006,
#   'f1-score': 0.9004224502112251,
#   'support': 861.0},
#  'male': {'precision': 0.9579524680073126,
#   'recall': 0.9812734082397003,
#   'f1-score': 0.969472710453284,
#   'support': 2670.0},
#  'accuracy': 0.9532710280373832,
#  'macro avg': {'precision': 0.9475691988277769,
#   'recall': 0.9238538934346004,
#   'f1-score': 0.9349475803322546,
#   'support': 3531.0},
#  'weighted avg': {'precision': 0.952888749647879,
#   'recall': 0.9532710280373832,
#   'f1-score': 0.9526354762226374,
#   'support': 3531.0}}

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_svc, display_labels=['female', 'male'])
plt.title('Confusion Matrix for Third Model')
plt.savefig('../images/confusion_matrix_svc_model.png')
plt.show()

# %% [markdown]
# This model correctly classified the vast majority of instances, outperforming both the Naive Bayes and Logistic Regression models.
#
# The recall for the "female" class is approximately 87%, which is a significant improvement over the Naive Bayes baseline and comparable to the Logistic Regression model. Importantly, the precision for the "female" class is also high at 93.7%, meaning when the model predicts "female", it is usually correct. This indicates a better balance between precision and recall for the minority class compared to the previous models.
#
# The LinearSVC model, tuned via GridSearchCV, provides the most robust and balanced solution for this classification task. It effectively handles the class imbalance while achieving high precision and recall for both genders, making it the preferred model for predicting the gender of the main actor from movie reviews.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Multinomial Naive Bayes (Baseline):
#
# - Performance: Achieved ~87% accuracy but failed critically on the minority class (Female), with a Recall of only 47%.
#
# - Verdict: Biased. The model defaulted to predicting "Male" too often due to the class imbalance. It was precise but not sensitive enough to be useful.
#
# Logistic Regression (with Class Weighting):
#
# - Performance: Accuracy improved to ~93.4%. The use of class_weight='balanced' successfully fixed the bias, boosting Female Recall to ~90%.
#
# - Trade-off: While it caught almost all female actors, it generated more False Positives (lower precision for females ~84%), meaning it sometimes guessed "Female" when it was actually "Male".
#
# - Verdict: Balanced but slightly imprecise. A massive improvement over the baseline.
#
# LinearSVC (Best Model):
#
# - Performance: This model achieved the best overall results with an Accuracy of 95.33%.
#
# - Why it wins: It offers the perfect compromise. It maintains a high Female Recall (86.6%) comparable to Logistic Regression but with significantly higher Precision (93.7%).
#
# - Verdict: The LinearSVC model minimizes both types of errors (False Positives and False Negatives) more effectively than the others. It distinguishes between the genders with the highest confidence and reliability.
#
# The LinearSVC model is the undisputed winner. It proves that for this specific text classification task, a Support Vector Machine (which works well in high-dimensional spaces like TF-IDF) combined with proper hyperparameter tuning yields the most robust predictor, effectively handling the dataset's inherent imbalance.
